# %%
from innolux import *

# %%
raw = pl.read_excel(
    data_path / "T1 6634 6053 製程改善" / "OM整理_20250924.xlsx", 
    sheet_id=2,
)
raw
# Out:
# shape: (56, 5)
# ┌──────────────┬──────────┬──────┬───────┬──────┐
# │ 條件         ┆ short ID ┆ 位置 ┆ 膠寬  ┆ 內衝 │
# │ ---          ┆ ---      ┆ ---  ┆ ---   ┆ ---  │
# │ str          ┆ str      ┆ str  ┆ str   ┆ i64  │
# ╞══════════════╪══════════╪══════╪═══════╪══════╡
# │ LC Pattern 1 ┆ 23A62    ┆ 左   ┆ 417.6 ┆ 0    │
# │ LC Pattern 1 ┆ 23A62    ┆ 上   ┆ 603.6 ┆ 0    │
# │ LC Pattern 1 ┆ 23A62    ┆ 右   ┆ 542.6 ┆ 0    │
# │ LC Pattern 1 ┆ 23A62    ┆ 下   ┆ 614.3 ┆ 0    │
# │ LC Pattern 1 ┆ 23A72    ┆ 左   ┆ 483.2 ┆ 0    │
# │ …            ┆ …        ┆ …    ┆ …     ┆ …    │
# │ LC Pattern 2 ┆ 24GC6    ┆ 下   ┆ 586.8 ┆ 0    │
# │ LC Pattern 2 ┆ 24GD6    ┆ 左   ┆ 557.2 ┆ 0    │
# │ LC Pattern 2 ┆ 24GD6    ┆ 上   ┆ 496.9 ┆ 0    │
# │ LC Pattern 2 ┆ 24GD6    ┆ 右   ┆ 535.1 ┆ 0    │
# │ LC Pattern 2 ┆ 24GD6    ┆ 下   ┆ 577.7 ┆ 0    │
# └──────────────┴──────────┴──────┴───────┴──────┘

# %%
px.box(
    raw, 
    x='位置',
    y='膠寬',
    color='條件',
)
