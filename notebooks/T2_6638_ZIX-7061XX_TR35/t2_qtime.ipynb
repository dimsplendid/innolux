# %%
from innolux import *

# %%
data_path = data_path / Path("T2 6628 BP 3500 A ZIX-7061 S-NP13 S-WB141")

# %%
station = {
    "PIPR": [
        
    ],
    "PIPB": [
        
    ],
    "PAUV": [
        
    ],
    "PAPB": [
        
    ],
    "SEAL": [
        "2CASM151",
        "2CASM152",
        "2CASM153",
        "2CASM154",
        "2CASM161",
        "2CASM162",
        "2CASM163",
        "2CASM251",
        "2CASM252",
        "2CASM253",
        "2CASM254",
        "2CASM261",
        "2CASM262",
        "2CASM263",
    ],
    "LCDP": [
        "2CASM1A1",
        "2CASM1A2",
        "2CASM1A3",
        "2CASM1A4",
        "2CASM2A1",
        "2CASM2A2",
        "2CASM2A3",
        "2CASM2A4",
    ],
    "ODFX": [
        "2CABM1B1",
        "2CABM1B2",
        "2CABM1B3",
        "2CASM2B1",
        "2CASM2B2",
        "2CASM2B3",
    ],
    "SEUV": [
        "2CABM1C1",
        "2CABM1C2",
    ],
    "SEPB": [
        "2CABM1D1",
        "2CABM1D2",
    ]
}
