# %%
from innolux import *
data_root = Path("../../tests/data").resolve() / Path("T2_6638_ZIX-7061XX_TR35")

# %%
Path("../../tests/data").resolve()
# Out:
# PosixPath('/Users/dimsplendid/Documents/innolux/tests/data')

# %%
edc_raws = pl.read_excel(data_root / '6638_TD實驗批_參數與Q-time_raw.xlsx', sheet_id=0)

# %%
edc_raws.keys()
# Out:
# dict_keys(['片號對照', 'TFT_Chamber', 'TFT_sub EQ', 'CF_SubEQ', 'CF_Chamber', '參數設定值', 'TFT_PIPR', 'TFT_PIPB', 'TFT_PHA', 'TFT_ASM', 'CF_PIPR', 'CF_PIPB', 'CF_PHA', 'CF_ARO'])

# %%
(
    edc_raws['TFT_ASM']
    .filter(pl.col('GLASS_ID')=="661A2AQ523R201")
    # .filter(pl.col('SUB_EQUIP_ID')==r"2CABM\dD\d")
    # .filter(pl.col('PARAM_NAME').str.contains('oven'))
)
# Out:
# shape: (250, 35)
# ┌──────────────┬──────────────┬──────────────┬──────────────┬───┬─────┬───────┬─────────────┬──────┐
# │ STEP_ID      ┆ GLASS_ID     ┆ PROCESS_STAR ┆ PROCESS_END_ ┆ … ┆ MIN ┆ COUNT ┆ PARAM_STR_V ┆ RN   │
# │ ---          ┆ ---          ┆ T_TIME       ┆ TIME         ┆   ┆ --- ┆ ---   ┆ ALUE        ┆ ---  │
# │ str          ┆ str          ┆ ---          ┆ ---          ┆   ┆ str ┆ str   ┆ ---         ┆ i64  │
# │              ┆              ┆ datetime[ms] ┆ datetime[ms] ┆   ┆     ┆       ┆ str         ┆      │
# ╞══════════════╪══════════════╪══════════════╪══════════════╪═══╪═════╪═══════╪═════════════╪══════╡
# │ 6310_AS1_ARO ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 1    │
# │              ┆ 01           ┆ 00:35:06     ┆ 01:32:18     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_ARO ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 2    │
# │              ┆ 01           ┆ 00:35:06     ┆ 01:32:18     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_ARO ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 3    │
# │              ┆ 01           ┆ 00:35:06     ┆ 01:32:18     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_ARO ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 4    │
# │              ┆ 01           ┆ 00:35:06     ┆ 01:32:18     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_ARO ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆ 6           ┆ 5    │
# │              ┆ 01           ┆ 00:35:06     ┆ 01:32:18     ┆   ┆     ┆       ┆             ┆      │
# │ …            ┆ …            ┆ …            ┆ …            ┆ … ┆ …   ┆ …     ┆ …           ┆ …    │
# │ 6310_AS1_UV_ ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 6973 │
# │ MA           ┆ 01           ┆ 00:35:06     ┆ 02:58:01     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_UV_ ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 6974 │
# │ MA           ┆ 01           ┆ 00:35:06     ┆ 02:58:01     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_UV_ ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 6975 │
# │ MA           ┆ 01           ┆ 00:35:06     ┆ 02:58:01     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_UV_ ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 6976 │
# │ MA           ┆ 01           ┆ 00:35:06     ┆ 02:58:01     ┆   ┆     ┆       ┆             ┆      │
# │ 6310_AS1_UV_ ┆ 661A2AQ523R2 ┆ 2026-06-18   ┆ 2026-06-18   ┆ … ┆     ┆       ┆             ┆ 6977 │
# │ MA           ┆ 01           ┆ 00:35:06     ┆ 02:58:01     ┆   ┆     ┆       ┆             ┆      │
# └──────────────┴──────────────┴──────────────┴──────────────┴───┴─────┴───────┴─────────────┴──────┘

# %%
station = {
    "PIPR": [
        
    ],
    "PIPB": [
        
    ],
    "PAUV": [
        
    ],
    "PAPB": [
        
    ],
    "SEAL": [
        "2CASM151",
        "2CASM152",
        "2CASM153",
        "2CASM154",
        "2CASM161",
        "2CASM162",
        "2CASM163",
        "2CASM251",
        "2CASM252",
        "2CASM253",
        "2CASM254",
        "2CASM261",
        "2CASM262",
        "2CASM263",
    ],
    "LCDP": [
        "2CASM1A1",
        "2CASM1A2",
        "2CASM1A3",
        "2CASM1A4",
        "2CASM2A1",
        "2CASM2A2",
        "2CASM2A3",
        "2CASM2A4",
    ],
    "ODFX": [
        "2CABM1B1",
        "2CABM1B2",
        "2CABM1B3",
        "2CASM2B1",
        "2CASM2B2",
        "2CASM2B3",
    ],
    "SEUV": [
        "2CABM1C1",
        "2CABM1C2",
    ],
    "SEPB": [
        "2CABM1D1",
        "2CABM1D2",
    ]
}
